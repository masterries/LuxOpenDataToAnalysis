# %% [markdown]
# # Data Scraper Example
#
# This notebook demonstrates how to use the flexible `DataScraper` class to download datasets from various sources.

# %%
# Import the DataScraper class and helper function
from ownlib.data_scraper import scrape_from_config
import pandas as pd
import os

# %% [markdown]
# ## Method 1: Using Direct Method Calls
#
# This approach gives you more control over the scraping process.

# %%
# Call the function, providing the path to your JSON configuration if needed
results = scrape_from_config()

# Display the results
print(results)
# Out:
# --- Processing site: Luxembourg Logements Rent ---
# Created folder at download/luxembourg_logements_rent
# Fetching HTML from https://data.public.lu/fr/datasets/loyers-annonces-des-logements-par-commune/
#
# Found 6 download links:
# 1.  - https://data.public.lu/fr/datasets/r/fb6616ef-a4c6-44ea-bf0c-74de9a81ab68
# 2. https://data.public.lu/fr/datasets/r/fb6616ef-a4c6-44ea-bf0c-74de9a81ab68 - https://data.public.lu/fr/datasets/r/fb6616ef-a4c6-44ea-bf0c-74de9a81ab68
# 3.  - https://data.public.lu/fr/datasets/r/e1e5485b-8a2e-4593-b1ea-226eb9299f0d
# 4. https://data.public.lu/fr/datasets/r/e1e5485b-8a2e-4593-b1ea-226eb9299f0d - https://data.public.lu/fr/datasets/r/e1e5485b-8a2e-4593-b1ea-226eb9299f0d
# 5.  - https://data.public.lu/fr/datasets/r/94e4a229-c564-4dd2-99b5-6b6e9d29eafd
# 6. https://data.public.lu/fr/datasets/r/94e4a229-c564-4dd2-99b5-6b6e9d29eafd - https://data.public.lu/fr/datasets/r/94e4a229-c564-4dd2-99b5-6b6e9d29eafd
# Processing file:
# ...
